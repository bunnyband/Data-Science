# %% [markdown]
# <a href="https://colab.research.google.com/github/bunnyband/sales-predictions/blob/main/18_Graphing_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from google.colab import drive
import datetime 

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filename = ('/content/drive/MyDrive/Personal Consumption Expenditures.xlsx')

df= pd.read_excel(filename)

df
# Out:
#                                                 Category  \
# 0                                    Alcoholic beverages
# 1                                    Alcoholic beverages
# 2                                    Alcoholic beverages
# 3                                    Alcoholic beverages
# 4                                    Alcoholic beverages
# ...                                                  ...
# 14895          Coffee, tea, and other beverage materials
# 14896  Mineral waters, soft drinks, and vegetable juices
# 14897                                Alcoholic beverages
# 14898                                Alcoholic beverages
# 14899                                Alcoholic beverages
#
#                                             Sub-Category      Month  \
# 0                                                   Beer 1976-01-01
# 1                                                   Beer 1976-02-01
# 2                                                   Beer 1976-03-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14900 entries, 0 to 14899
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             14900 non-null  object
#  1   Sub-Category         14900 non-null  object
#  2   Month                14900 non-null  datetime64[ns]
#  3   Millions of Dollars  14900 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 465.8+ KB

# %%
# Check for duplicate data

df.duplicated().sum()
# Out:
# 0

# %%
df['Category'].value_counts()
# Out:
# Meats and poultry                                    2980
# Alcoholic beverages                                  2235
# Milk, dairy products, and eggs                       2235
# Cereals and bakery products                          1490
# Fresh fruits and vegetables                          1490
# Fats and oils                                         745
# Fish and seafood                                      745
# Processed fruits and vegetables                       745
# Sugar and sweets                                      745
# Coffee, tea, and other beverage materials             745
# Mineral waters, soft drinks, and vegetable juices     745
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Beer                                                 745
# Spirits                                              745
# Coffee, tea, and other beverage materials            745
# Sugar and sweets                                     745
# Processed fruits and vegetables                      745
# Processed dairy products                             745
# Fresh milk                                           745
# Eggs                                                 745
# Poultry                                              745
# Pork                                                 745
# Other meats                                          745
# Beef and veal                                        745
# Vegetables (fresh)                                   745
# Fruit (fresh)                                        745
# Fish and seafood                                     745
# Fats and oils                                        745
# ...

# %%
df['Month'].value_counts()
# Out:
# 1976-01-01    20
# 2000-09-01    20
# 1999-12-01    20
# 2000-01-01    20
# 2000-02-01    20
#               ..
# 1964-12-01    20
# 1965-01-01    20
# 1965-02-01    20
# 1965-03-01    20
# 2021-01-01    20
# Name: Month, Length: 745, dtype: int64

# %%
# Check for missing data

df.isnull().sum()
# Out:
# Category               0
# Sub-Category           0
# Month                  0
# Millions of Dollars    0
# dtype: int64

# %%
#Selecting Data After July 31, 2020

x = datetime.datetime(1999, 12, 31)

# %%
df_Cat = df.groupby(['Category']).sum()

df_Cat
# Out:
#                                                    Millions of Dollars
# Category
# Alcoholic beverages                                           42788825
# Cereals and bakery products                                   45346246
# Coffee, tea, and other beverage materials                      4907531
# Fats and oils                                                  7150128
# Fish and seafood                                               5147746
# Fresh fruits and vegetables                                   25508261
# Meats and poultry                                             58128964
# Milk, dairy products, and eggs                                29598868
# Mineral waters, soft drinks, and vegetable juices             28565554
# Processed fruits and vegetables                               11155424
# Sugar and sweets                                              16850590

# %%
df_SubCat = df.groupby(['Sub-Category']).sum()

df_SubCat
# Out:
#                                                    Millions of Dollars
# Sub-Category
# Bakery products                                               29460056
# Beef and veal                                                 18899624
# Beer                                                          22049609
# Cereals                                                       15886190
# Coffee, tea, and other beverage materials                      4907531
# Eggs                                                           3718272
# Fats and oils                                                  7150128
# Fish and seafood                                               5147746
# Fresh milk                                                    10196098
# Fruit (fresh)                                                 10924146
# Mineral waters, soft drinks, and vegetable juices             28565554
# Other meats                                                   10541361
# ...

# %%
sns.barplot(x = 'Category', y = 'Millions of Dollars', data = df)
sns.set(rc={'figure.figsize':(50,25)})

plt.xticks(rotation=90, fontsize = 30)
plt.yticks(fontsize = 30)
plt.title('Items sold from 1972 - 2021', fontsize = 30)
plt.xlabel('Category of Purchases', fontsize = 30)
plt.ylabel('Millions of Dollars', fontsize = 40, labelpad = 50)
# Out:
# Text(0, 0.5, 'Millions of Dollars')

# %%
sns.barplot(x = 'Sub-Category', y = 'Millions of Dollars', data = df)
sns.set(rc={'figure.figsize':(30,15)})

plt.xticks(rotation=90, fontsize = 30)
plt.yticks(fontsize = 30)
plt.title('Items sold from 1972 - 2021', fontsize = 40)
plt.xlabel('Sub-Category of Purchases', fontsize = 30)
plt.ylabel('Millions of Dollars', fontsize = 40, labelpad = 50)

plt.savefig('Graph.png', dpi = 1200)
